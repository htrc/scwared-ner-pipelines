# %%
import spacy
import pandas as pd

# %% [markdown]
# # AIJ dataset

# %%
# !head aijwikinereswp2
# Out:
# El|ART|O Principado|NC|I-LOC de|PREP|I-LOC Andorra|NP|I-LOC es|VSfin|O un|ART|O peque�o|ADJ|O pa�s|NC|O del|PDEL|O sur|PE|O de|PREP|O Europa|NP|I-LOC con|PREP|O una|ART|O extensi�n|NC|O de|PREP|O 468|CARD|O km|UMMX|O 2|CARD|O ,|CM|O situado|VLadj|O en|PREP|O los|ART|O Pirineos|NC|I-LOC entre|PREP|O Espa�a|NP|I-LOC y|CC|O Francia|NP|I-LOC ,|CM|O con|PREP|O una|ART|O altitud|NC|O media|ADJ|O de|PREP|O 1.996|CARD|O metros|NC|O sobre|PREP|O el|ART|O nivel|NC|O del|PDEL|O mar|NC|O .|FS|O
# Su|NP|O territorio|NC|O ,|CM|O con|PREP|O capital|NC|O en|PREP|O Andorra|NP|I-LOC la|ART|I-LOC Vieja|NP|I-LOC ,|CM|O est�|VEfin|O formado|VLadj|O por|PREP|O siete|CARD|O parroquias|NC|O con|PREP|O una|ART|O poblaci�n|NC|O total|ADJ|O de|PREP|O 84.484|CARD|O habitantes|NC|O en|PREP|O 2008|CARD|O .|FS|O
# No|NEG|O tiene|VLfin|O fuerzas|NC|O armadas|VLadj|O propias|ADJ|O y|CC|O su|PPO|O defensa|NC|O es|VSfin|O responsabilidad|NC|O de|PREP|O Espa�a|NP|I-LOC y|CC|O Francia|NP|I-LOC .|FS|O
# Durante|PREP|O mucho|QU|O tiempo|NC|O pobre|ADJ|O y|CC|O aislado|VLadj|O ,|CM|O ha|VHfin|O conseguido|VLadj|O una|ART|O notable|ADJ|O prosperidad|NC|O desde|PREP|O la|ART|O II|NP|I-MISC Guerra|NP|I-MISC Mundial|NP|I-MISC a|PREP|O trav�s|NC|O del|PDEL|O turismo|NC|O y|CC|O ,|CM|O especialmente|ADV|O ,|CM|O por|PREP|O su|PPO|O condici�n|NC|O de|PREP|O para�so|NC|O fiscal|ADJ|O .|FS|O
# Debido|ADJ|O a|PREP|O la|ART|O fertilidad|NC|O de|PREP|O las|ART|O tierras|NC|O ,|CM|O estos|DM|O grupos|NC|O las|PPC|O cultivaron|VLfin|O y|CC|O se|SE|O establecieron|VLfin|O definitivamente|ADV|O ,|CM|O recibiendo|VLger|O de|PREP|O los|ART|O pueblos|NC|O que|CQUE|O pasaron|VLfin|O por|PREP|O su|PPO|O territorio|NC|O ,|CM|O la|ART|O cultura|NC|O del|PDEL|O bronce|NC|O al|PAL|O beneficiarse|VLinf|O de|PREP|O los|ART|O metales|NC|O que|CQUE|O hab�an|VHfin|O en|PREP|O Arinsal|NP|I-LOC .|FS|O
# Con|PREP|O la|ART|O expansi�n|NC|O de|PREP|O este|DM|O condado|NC|O hacia|PREP|O el|ART|O sur|PE|O ,|CM|O donde|ADV|O hab�a|VHfin|O terrenos|NC|O m�s|ADV|O f�rtiles|ADJ|O ,|CM|O las|ART|O zonas|NC|O monta�osas|ADJ|O dejaron|VLfin|O de|CSUBI|O tener|VLinf|O inter�s|NC|O para|PREP|O el|ART|O conde|NC|O y|CC|O ,|CM|O en|PREP|O el|ART|O a�o|NC|O 1133|CODE|O ,|CM|O Ermengol|NP|I-PER VI|CARD|I-PER cede|VLfin|O todos|QU|O los|ART|O bienes|NC|O y|CC|O derechos|NC|O adquiridos|VLadj|O sobre|PREP|O los|ART|O valles|NC|O de|PREP|O Andorra|NP|I-LOC al|PAL|O obispo|NC|I-LOC de|PREP|I-LOC Urgel|NP|I-LOC .|FS|O
# Ante|VLfin|O el|ART|O reinado|NC|O de|PREP|O Boris|NP|I-PER I|CARD|I-PER ,|CM|O el|ART|O 8|CARD|O de|PREP|O julio|NC|O Francia|NP|I-LOC comunic�|VLfin|O oficialmente|ADV|O que|CQUE|O no|NEG|O intervendr�a|VLfin|O en|PREP|O Andorra|NP|I-LOC .|FS|O
# El|ART|O jefe|NC|O de|PREP|O gobierno|NC|O actual|ADJ|O es|VSfin|O Jaume|NP|I-PER Bartumeu|NP|I-PER Cassany|NP|I-PER .|FS|O
# El|ART|O Consejo|NC|I-ORG General|ADJ|I-ORG de|PREP|I-ORG los|ART|I-ORG Valles|NC|I-ORG de|PREP|I-ORG Andorra|NP|I-ORG es|VSfin|O el|ART|O �rgano|NC|O legislativo|ADJ|O y|CC|O se|SE|O trata|VLfin|O de|PREP|O un|ART|O parlamento|NC|O unicameral|ADJ|O de|PREP|O representaci�n|NC|O mixta|ADJ|O y|CC|O paritaria|ADJ|O de|PREP|O la|ART|O poblaci�n|NC|O nacional|ADJ|O y|CC|O de|PREP|O las|ART|O siete|CARD|O parroquias|NC|O ,|CM|O compuesto|VLadj|O por|PREP|O 28|CARD|O miembros|NC|O elegidos|VLadj|O cada|QU|O cuatro|CARD|O a�os|NC|O .|FS|O

# %%
# read aijwikinereswp
# UTF-8 does not work with this dataset (strange charset)
with open("aijwikinereswp2","r",encoding="ISO 8859-1") as file:
    sentences = []
    for l in file:
        sent = l.replace("\n","").split(" ")
        if sent != ['']:
            sentences.append(l.replace("\n","").split(" "))

# %% [markdown]
# # only for wikiner, split train and test manually

# %%
train_idx = int(.6 * len(sentences))
test_idx = int(.8 * len(sentences))

# %%
len(sentences)
# Out:
# 128355

# %%
train_list = []
test_list = []
val_list = []

f_name = "aijwikinereswp2"
sent_id = 0
for sent in sentences[:train_idx]:
    for t in sent:
        ent = t.split("|")
        train_list.append((t,f_name,sent_id,ent[0],ent[2]))
    #train_list.append(("",f_name))
    sent_id+=1

sent_id = 0
for sent in sentences[train_idx:test_idx]:
    for t in sent:
        ent = t.split("|")        
        test_list.append((t,f_name,sent_id,ent[0],ent[2]))
    sent_id+=1
    
sent_id = 0
for sent in sentences[test_idx:]:
    for t in sent:
        ent = t.split("|")        
        val_list.append((t,f_name,sent_id,ent[0],ent[2]))
    sent_id+=1

# %%
pd.DataFrame(train_list).loc[:50]
# Out:
#                       0                1  2           3      4
# 0              El|ART|O  aijwikinereswp2  0          El      O
# 1   Principado|NC|I-LOC  aijwikinereswp2  0  Principado  I-LOC
# 2         de|PREP|I-LOC  aijwikinereswp2  0          de  I-LOC
# 3      Andorra|NP|I-LOC  aijwikinereswp2  0     Andorra  I-LOC
# 4            es|VSfin|O  aijwikinereswp2  0          es      O
# 5              un|ART|O  aijwikinereswp2  0          un      O
# 6         pequeño|ADJ|O  aijwikinereswp2  0     pequeño      O
# 7             país|NC|O  aijwikinereswp2  0        país      O
# 8            del|PDEL|O  aijwikinereswp2  0         del      O
# 9              sur|PE|O  aijwikinereswp2  0         sur      O
# 10            de|PREP|O  aijwikinereswp2  0          de      O
# 11      Europa|NP|I-LOC  aijwikinereswp2  0      Europa  I-LOC
# 12           con|PREP|O  aijwikinereswp2  0         con      O
# 13            una|ART|O  aijwikinereswp2  0         una      O
# 14       extensión|NC|O  aijwikinereswp2  0   extensión      O
# 15            de|PREP|O  aijwikinereswp2  0          de      O
# 16           468|CARD|O  aijwikinereswp2  0         468      O
# 17            km|UMMX|O  aijwikinereswp2  0          km      O
# 18             2|CARD|O  aijwikinereswp2  0           2      O
# 19               ,|CM|O  aijwikinereswp2  0           ,      O
# 20      situado|VLadj|O  aijwikinereswp2  0     situado      O
# 21            en|PREP|O  aijwikinereswp2  0          en      O
# 22            los|ART|O  aijwikinereswp2  0         los      O
# 23    Pirineos|NC|I-LOC  aijwikinereswp2  0    Pirineos  I-LOC
# 24         entre|PREP|O  aijwikinereswp2  0       entre      O
# 25      España|NP|I-LOC  aijwikinereswp2  0      España  I-LOC
# 26               y|CC|O  aijwikinereswp2  0           y      O
# 27     Francia|NP|I-LOC  aijwikinereswp2  0     Francia  I-LOC
# 28               ,|CM|O  aijwikinereswp2  0           ,      O
# 29           con|PREP|O  aijwikinereswp2  0         con      O
# 30            una|ART|O  aijwikinereswp2  0         una      O
# 31         altitud|NC|O  aijwikinereswp2  0     altitud      O
# 32          media|ADJ|O  aijwikinereswp2  0       media      O
# 33            de|PREP|O  aijwikinereswp2  0          de      O
# 34         1.996|CARD|O  aijwikinereswp2  0       1.996      O
# 35          metros|NC|O  aijwikinereswp2  0      metros      O
# 36         sobre|PREP|O  aijwikinereswp2  0       sobre      O
# 37             el|ART|O  aijwikinereswp2  0          el      O
# 38           nivel|NC|O  aijwikinereswp2  0       nivel      O
# 39           del|PDEL|O  aijwikinereswp2  0         del      O
# 40             mar|NC|O  aijwikinereswp2  0         mar      O
# 41               .|FS|O  aijwikinereswp2  0           .      O
# 42              Su|NP|O  aijwikinereswp2  1          Su      O
# 43      territorio|NC|O  aijwikinereswp2  1  territorio      O
# 44               ,|CM|O  aijwikinereswp2  1           ,      O
# 45           con|PREP|O  aijwikinereswp2  1         con      O
# 46         capital|NC|O  aijwikinereswp2  1     capital      O
# 47            en|PREP|O  aijwikinereswp2  1          en      O
# 48     Andorra|NP|I-LOC  aijwikinereswp2  1     Andorra  I-LOC
# 49         la|ART|I-LOC  aijwikinereswp2  1          la  I-LOC
# 50       Vieja|NP|I-LOC  aijwikinereswp2  1       Vieja  I-LOC

# %%
pd.DataFrame(train_list).groupby(1).count()
# Out:
#                        0        2        3        4
# 1
# aijwikinereswp2  2120490  2120490  2120490  2120490

# %% [markdown]
# # panx dataset

# %%
# read aijwikinereswp
# UTF-8 does not work with this dataset (strange charset)
with open("es/train","r",encoding="ISO 8859-1") as file:
    sentences = []
    for l in file:
        #print(l)
        sent = l[3:].replace("\n","")#.split("\t")
        #if sent != ['']:
        sentences.append(sent)

# %%
f_name = "pannx"

sent_id = 0
for r in pd.read_csv("es/train",sep="\t",header=None,skip_blank_lines=False).to_records():
    if not pd.isna(r["0"]):
        token = "es:".join(r["0"].split("es:")[1:])
        train_list.append((r,f_name,sent_id,token,r["1"]))
    else:
        sent_id+=1
    

"""
sent_id = 0
for sent in sentences:
    ent = sent.split("\t")
    try:
        train_list.append((sent,f_name,sent_id,ent[0],ent[1]))
    except:
        pass
    if sent == "":
        sent_id+=1
    #train_list.append(("",f_name))
"""
# Out:
# '\nsent_id = 0\nfor sent in sentences:\n    ent = sent.split("\t")\n    try:\n        train_list.append((sent,f_name,sent_id,ent[0],ent[1]))\n    except:\n        pass\n    if sent == "":\n        sent_id+=1\n    #train_list.append(("",f_name))\n'

# %%
# read aijwikinereswp
# UTF-8 does not work with this dataset (strange charset)
with open("es/test","r",encoding="ISO 8859-1") as file:
    sentences = []
    for l in file:
        #print(l)
        sent = l[3:].replace("\n","")#.split("\t")
        #if sent != ['']:
        sentences.append(sent)

# %%
f_name = "pannx"

sent_id = 0
for r in pd.read_csv("es/test",sep="\t",header=None).to_records():
    if not pd.isna(r["0"]):
        token = "es:".join(r["0"].split("es:")[1:])
        test_list.append((r,f_name,sent_id,token,r["1"]))
    else:
        sent_id+=1
    
"""
sent_id = 0
for sent in sentences:
    ent = sent.split("\t")
    try:
        test_list.append((sent,f_name,sent_id,ent[0],ent[1]))
    except:
        pass
    if sent == "":
        sent_id+=1
    #train_list.append(("",f_name))
"""
# Out:
# '\nsent_id = 0\nfor sent in sentences:\n    ent = sent.split("\t")\n    try:\n        test_list.append((sent,f_name,sent_id,ent[0],ent[1]))\n    except:\n        pass\n    if sent == "":\n        sent_id+=1\n    #train_list.append(("",f_name))\n'

# %%
# read aijwikinereswp
# UTF-8 does not work with this dataset (strange charset)
with open("es/dev","r",encoding="ISO 8859-1") as file:
    sentences = []
    for l in file:
        #print(l)
        sent = l[3:].replace("\n","")#.split("\t")
        #if sent != ['']:
        sentences.append(sent)

# %%
f_name = "pannx"

sent_id = 0
for r in pd.read_csv("es/dev",sep="\t",header=None).to_records():
    if not pd.isna(r["0"]):
        token = "es:".join(r["0"].split("es:")[1:])
        val_list.append((r,f_name,sent_id,token,r["1"]))
    else:
        sent_id+=1
        
"""
sent_id = 0
for sent in sentences:
    ent = sent.split("\t")    
    try:
        val_list.append((sent,f_name,sent_id,ent[0],ent[1]))
    except:
        pass
    if sent == "":
        sent_id+=1
    #train_list.append(("",f_name))
"""
# Out:
# '\nsent_id = 0\nfor sent in sentences:\n    ent = sent.split("\t")    \n    try:\n        val_list.append((sent,f_name,sent_id,ent[0],ent[1]))\n    except:\n        pass\n    if sent == "":\n        sent_id+=1\n    #train_list.append(("",f_name))\n'

# %%
pd.DataFrame(train_list).groupby(1).count()
# Out:
#                        0        2        3        4
# 1
# aijwikinereswp2  2120490  2120490  2120490  2120490
# pannx             129283   129283   129283   129283

# %% [markdown]
# # wikineural

# %%
# preprocess wikineural dataset
label_token = {'O': 0, 'B-PER': 1, 'I-PER': 2, 'B-ORG': 3, 'I-ORG': 4, 'B-LOC': 5, 'I-LOC': 6, 'B-MISC': 7, 'I-MISC': 8}
label_id = {v:k for k,v in label_token.items()}
label_id
# Out:
# {0: 'O',
#  1: 'B-PER',
#  2: 'I-PER',
#  3: 'B-ORG',
#  4: 'I-ORG',
#  5: 'B-LOC',
#  6: 'I-LOC',
#  7: 'B-MISC',
#  8: 'I-MISC'}

# %%
# read aijwikinereswp
# UTF-8 does not work with this dataset (strange charset)

            
import json
with open("wikineural/train_es.jsonl","r") as file:
    sentences = []
    for l in file:
        jj = json.loads(l)
        tok = jj["tokens"]
        ner = [label_id[x] for x in jj["ner_tags"]]
        list_tok = list(zip(tok,ner))
        #sent = []
        #for x in list_tok:
        #    sent.append("{}".format(" ".join(x)))
        sentences.append(list_tok)

# %%
f_name = "wikineural"
sent_id = 0
for sent in sentences:
    for t in sent:
        train_list.append((t,f_name,sent_id,t[0],t[1]))
    sent_id+=1

# %%
# read aijwikinereswp
# UTF-8 does not work with this dataset (strange charset)

            
import json
with open("wikineural/test_es.jsonl","r") as file:
    sentences = []
    for l in file:
        jj = json.loads(l)
        tok = jj["tokens"]
        ner = [label_id[x] for x in jj["ner_tags"]]
        list_tok = list(zip(tok,ner))
        #sent = []
        #for x in list_tok:
        #    sent.append("{}".format(" ".join(x)))
        sentences.append(list_tok)

# %%
f_name = "wikineural"
sent_id = 0
for sent in sentences:
    for t in sent:
        test_list.append((t,f_name,sent_id,t[0],t[1]))
    sent_id+=1

# %%
# read aijwikinereswp
# UTF-8 does not work with this dataset (strange charset)

            
import json
with open("wikineural/val_es.jsonl","r") as file:
    sentences = []
    for l in file:
        jj = json.loads(l)
        tok = jj["tokens"]
        ner = [label_id[x] for x in jj["ner_tags"]]
        list_tok = list(zip(tok,ner))
        #sent = []
        #for x in list_tok:
        #    sent.append("{}".format(" ".join(x)))
        sentences.append(list_tok)

# %%
f_name = "wikineural"
sent_id = 0
for sent in sentences:
    for t in sent:
        val_list.append((t,f_name,sent_id,t[0],t[1]))
    sent_id+=1

# %%
pd.DataFrame(train_list).groupby(1).count()
# Out:
#                        0        2        3        4
# 1
# aijwikinereswp2  2120490  2120490  2120490  2120490
# pannx             129283   129283   129283   129283
# wikineural       1883877  1883877  1883877  1883877

# %%
pd.DataFrame(train_list)
# Out:
#                            0                1      2           3      4
# 0                   El|ART|O  aijwikinereswp2      0          El      O
# 1        Principado|NC|I-LOC  aijwikinereswp2      0  Principado  I-LOC
# 2              de|PREP|I-LOC  aijwikinereswp2      0          de  I-LOC
# 3           Andorra|NP|I-LOC  aijwikinereswp2      0     Andorra  I-LOC
# 4                 es|VSfin|O  aijwikinereswp2      0          es      O
# ...                      ...              ...    ...         ...    ...
# 4133645              (en, O)       wikineural  76319          en      O
# 4133646            (2012, O)       wikineural  76319        2012      O
# 4133647               (y, O)       wikineural  76319           y      O
# 4133648            (2016, O)       wikineural  76319        2016      O
# 4133649               (., O)       wikineural  76319           .      O
#
# [4133650 rows x 5 columns]

# %%
pd.DataFrame(train_list)[[1,2,3,4]].groupby(1).max()
# Out:
#                      2      3  4
# 1
# aijwikinereswp2  77012  útima  O
# pannx            19999  우휴모탁국  O
# wikineural       76319     버선  O

# %% [markdown]
# # Randomize training set so neural network will not learn about dataset pattern

# %%
train_rd = pd.DataFrame(train_list)

# %%
train_rd.groupby([1,2]).count().index
# Out:
# MultiIndex([('aijwikinereswp2',     0),
#             ('aijwikinereswp2',     1),
#             ('aijwikinereswp2',     2),
#             ('aijwikinereswp2',     3),
#             ('aijwikinereswp2',     4),
#             ('aijwikinereswp2',     5),
#             ('aijwikinereswp2',     6),
#             ('aijwikinereswp2',     7),
#             ('aijwikinereswp2',     8),
#             ('aijwikinereswp2',     9),
#             ...
#             (     'wikineural', 76310),
#             (     'wikineural', 76311),
#             (     'wikineural', 76312),
#             (     'wikineural', 76313),
#             (     'wikineural', 76314),
#             (     'wikineural', 76315),
#             (     'wikineural', 76316),
#             (     'wikineural', 76317),
#             (     'wikineural', 76318),
#             (     'wikineural', 76319)],
#            names=[1, 2], length=173333)

# %%
import random
random.seed(777)
random_index = list(train_rd.groupby([1,2]).count().index)
random.shuffle(random_index)

# %%
random_index
# Out:
# [('wikineural', 62328),
#  ('aijwikinereswp2', 57493),
#  ('wikineural', 40597),
#  ('wikineural', 60686),
#  ('aijwikinereswp2', 39064),
#  ('aijwikinereswp2', 62153),
#  ('wikineural', 35361),
#  ('wikineural', 8647),
#  ('aijwikinereswp2', 73741),
#  ('aijwikinereswp2', 53306),
#  ('aijwikinereswp2', 56603),
#  ('aijwikinereswp2', 29055),
#  ('wikineural', 62185),
#  ('wikineural', 69812),
#  ('wikineural', 4873),
#  ('aijwikinereswp2', 30058),
#  ('aijwikinereswp2', 18600),
#  ('aijwikinereswp2', 64165),
#  ('aijwikinereswp2', 38629),
#  ('pannx', 2585),
#  ('wikineural', 59313),
#  ('wikineural', 9691),
#  ('aijwikinereswp2', 39625),
#  ('aijwikinereswp2', 68764),
#  ('wikineural', 6981),
#  ('wikineural', 37263),
#  ('aijwikinereswp2', 41975),
#  ('wikineural', 63898),
#  ('aijwikinereswp2', 15347),
#  ('aijwikinereswp2', 23642),
#  ('wikineural', 39258),
#  ('pannx', 9880),
#  ('aijwikinereswp2', 73761),
#  ('pannx', 7987),
#  ('wikineural', 75225),
#  ('wikineural', 32099),
#  ('wikineural', 63165),
#  ('aijwikinereswp2', 35669),
#  ('wikineural', 38769),
#  ('pannx', 11371),
#  ('aijwikinereswp2', 34442),
#  ('pannx', 9449),
#  ('wikineural', 65813),
#  ('pannx', 15023),
#  ('wikineural', 72459),
#  ('wikineural', 11103),
#  ('aijwikinereswp2', 30775),
#  ('wikineural', 14956),
#  ('wikineural', 5882),
#  ('aijwikinereswp2', 1535),
#  ('wikineural', 6220),
#  ('wikineural', 40194),
#  ('aijwikinereswp2', 71347),
#  ('pannx', 3134),
#  ('aijwikinereswp2', 16103),
#  ('aijwikinereswp2', 67829),
#  ('aijwikinereswp2', 16045),
#  ('aijwikinereswp2', 48806),
#  ('wikineural', 15176),
#  ('pannx', 13220),
#  ('aijwikinereswp2', 3361),
#  ('pannx', 13236),
#  ('aijwikinereswp2', 68804),
#  ('pannx', 16877),
#  ('aijwikinereswp2', 6109),
#  ('wikineural', 1518),
#  ('aijwikinereswp2', 73144),
#  ('pannx', 18272),
#  ('wikineural', 63713),
#  ('wikineural', 24285),
#  ('aijwikinereswp2', 68553),
#  ('wikineural', 60893),
#  ('aijwikinereswp2', 58946),
#  ('wikineural', 12673),
#  ('pannx', 5615),
#  ('wikineural', 68058),
#  ('pannx', 13727),
#  ('aijwikinereswp2', 68008),
#  ('wikineural', 59856),
#  ('aijwikinereswp2', 37697),
#  ('aijwikinereswp2', 72141),
#  ('aijwikinereswp2', 4990),
#  ('wikineural', 50732),
#  ('wikineural', 10075),
#  ('aijwikinereswp2', 56754),
#  ('aijwikinereswp2', 67313),
#  ('pannx', 6339),
#  ('aijwikinereswp2', 39962),
#  ('wikineural', 63900),
#  ('aijwikinereswp2', 41185),
#  ('wikineural', 60018),
#  ('wikineural', 44345),
#  ('wikineural', 861),
#  ('aijwikinereswp2', 34645),
#  ('wikineural', 2832),
#  ('aijwikinereswp2', 51074),
#  ('wikineural', 14285),
#  ('wikineural', 22541),
#  ('aijwikinereswp2', 27842),
#  ('wikineural', 15517),
#  ('wikineural', 27236),
#  ('aijwikinereswp2', 28836),
#  ('wikineural', 31448),
#  ('wikineural', 19841),
#  ('pannx', 8140),
#  ('wikineural', 65654),
#  ('aijwikinereswp2', 31589),
#  ('aijwikinereswp2', 8478),
#  ('wikineural', 68843),
#  ('wikineural', 34672),
#  ('wikineural', 59664),
#  ('aijwikinereswp2', 29094),
#  ('pannx', 3081),
#  ('pannx', 15905),
#  ('pannx', 8332),
#  ('wikineural', 3613),
#  ('pannx', 2622),
#  ('aijwikinereswp2', 73799),
#  ('aijwikinereswp2', 21351),
#  ('wikineural', 76233),
#  ('pannx', 3579),
#  ('wikineural', 14219),
#  ('aijwikinereswp2', 29086),
#  ('aijwikinereswp2', 58607),
#  ('aijwikinereswp2', 23087),
#  ('aijwikinereswp2', 36357),
#  ('wikineural', 9348),
#  ('wikineural', 28586),
#  ('wikineural', 69000),
#  ('aijwikinereswp2', 73392),
#  ('pannx', 2905),
#  ('wikineural', 13627),
#  ('aijwikinereswp2', 64661),
#  ('aijwikinereswp2', 50641),
#  ('wikineural', 69802),
#  ('aijwikinereswp2', 38249),
#  ('wikineural', 44067),
#  ('wikineural', 22122),
#  ('aijwikinereswp2', 32929),
#  ('aijwikinereswp2', 23114),
#  ('pannx', 19249),
#  ('wikineural', 48168),
#  ('aijwikinereswp2', 27665),
#  ('aijwikinereswp2', 54267),
#  ('wikineural', 4076),
#  ('aijwikinereswp2', 20088),
#  ('wikineural', 76283),
#  ('wikineural', 5957),
#  ('pannx', 2671),
#  ('aijwikinereswp2', 6487),
#  ('aijwikinereswp2', 13605),
#  ('aijwikinereswp2', 39755),
#  ('aijwikinereswp2', 34905),
#  ('aijwikinereswp2', 17682),
#  ('aijwikinereswp2', 5083),
#  ('wikineural', 48558),
#  ('wikineural', 60343),
#  ('aijwikinereswp2', 74432),
#  ('wikineural', 38211),
#  ('aijwikinereswp2', 14365),
#  ('wikineural', 68742),
#  ('aijwikinereswp2', 74886),
#  ('aijwikinereswp2', 58316),
#  ('wikineural', 63093),
#  ('aijwikinereswp2', 68127),
#  ('wikineural', 36004),
#  ('aijwikinereswp2', 52840),
#  ('pannx', 1384),
#  ('wikineural', 10224),
#  ('pannx', 11378),
#  ('aijwikinereswp2', 72282),
#  ('wikineural', 28364),
#  ('wikineural', 55054),
#  ('pannx', 16449),
#  ('aijwikinereswp2', 48510),
#  ('aijwikinereswp2', 52851),
#  ('aijwikinereswp2', 43514),
#  ('aijwikinereswp2', 27412),
#  ('wikineural', 45450),
#  ('aijwikinereswp2', 35025),
#  ('wikineural', 72979),
#  ('wikineural', 55921),
#  ('wikineural', 69035),
#  ('aijwikinereswp2', 42053),
#  ('wikineural', 33753),
#  ('wikineural', 70078),
#  ('wikineural', 45429),
#  ('wikineural', 61810),
#  ('pannx', 8994),
#  ('aijwikinereswp2', 18208),
#  ('aijwikinereswp2', 42596),
#  ('wikineural', 40365),
#  ('wikineural', 30652),
#  ('aijwikinereswp2', 54637),
#  ('pannx', 6638),
#  ('aijwikinereswp2', 40844),
#  ('wikineural', 38989),
#  ('aijwikinereswp2', 21897),
#  ('pannx', 18544),
#  ('wikineural', 20494),
#  ('aijwikinereswp2', 49761),
#  ('aijwikinereswp2', 23215),
#  ('wikineural', 33503),
#  ('wikineural', 59147),
#  ('wikineural', 952),
#  ('pannx', 7614),
#  ('aijwikinereswp2', 67082),
#  ('aijwikinereswp2', 76999),
#  ('wikineural', 35388),
#  ('wikineural', 63872),
#  ('aijwikinereswp2', 32913),
#  ('pannx', 7706),
#  ('wikineural', 12741),
#  ('aijwikinereswp2', 22216),
#  ('aijwikinereswp2', 26757),
#  ('aijwikinereswp2', 34134),
#  ('aijwikinereswp2', 32664),
#  ('aijwikinereswp2', 73651),
#  ('wikineural', 1666),
#  ('pannx', 10427),
#  ('wikineural', 73184),
#  ('aijwikinereswp2', 4117),
#  ('wikineural', 29592),
#  ('aijwikinereswp2', 63139),
#  ('wikineural', 62680),
#  ('pannx', 4003),
#  ('wikineural', 56326),
#  ('pannx', 8301),
#  ('aijwikinereswp2', 51949),
#  ('aijwikinereswp2', 37018),
#  ('aijwikinereswp2', 46185),
#  ('wikineural', 59618),
#  ('wikineural', 7222),
#  ('aijwikinereswp2', 64933),
#  ('wikineural', 52690),
#  ('pannx', 16913),
#  ('aijwikinereswp2', 26258),
#  ('wikineural', 67259),
#  ('aijwikinereswp2', 6966),
#  ('wikineural', 44492),
#  ('pannx', 13362),
#  ('aijwikinereswp2', 19025),
#  ('aijwikinereswp2', 67425),
#  ('pannx', 7517),
#  ('aijwikinereswp2', 75959),
#  ('aijwikinereswp2', 31385),
#  ('wikineural', 8306),
#  ('wikineural', 22821),
#  ('pannx', 16690),
#  ('aijwikinereswp2', 36711),
#  ('aijwikinereswp2', 49156),
#  ('aijwikinereswp2', 36238),
#  ('wikineural', 48718),
#  ('wikineural', 21229),
#  ('wikineural', 22634),
#  ('wikineural', 1159),
#  ('aijwikinereswp2', 71842),
#  ('wikineural', 36157),
#  ('aijwikinereswp2', 69114),
#  ('wikineural', 23829),
#  ('wikineural', 73528),
#  ('aijwikinereswp2', 73989),
#  ('aijwikinereswp2', 53801),
#  ('wikineural', 71816),
#  ('aijwikinereswp2', 57445),
#  ('wikineural', 45184),
#  ('wikineural', 52544),
#  ('wikineural', 44216),
#  ('pannx', 7113),
#  ('pannx', 12818),
#  ('aijwikinereswp2', 72184),
#  ('aijwikinereswp2', 54985),
#  ('aijwikinereswp2', 12616),
#  ('aijwikinereswp2', 28574),
#  ('aijwikinereswp2', 20059),
#  ('aijwikinereswp2', 4696),
#  ('aijwikinereswp2', 63765),
#  ('pannx', 11542),
#  ('aijwikinereswp2', 10497),
#  ('wikineural', 35396),
#  ('wikineural', 19247),
#  ('pannx', 9318),
#  ('wikineural', 65833),
#  ('pannx', 14595),
#  ('aijwikinereswp2', 43930),
#  ('wikineural', 6182),
#  ('aijwikinereswp2', 25592),
#  ('aijwikinereswp2', 15688),
#  ('aijwikinereswp2', 3275),
#  ('aijwikinereswp2', 11462),
#  ('aijwikinereswp2', 3885),
#  ('wikineural', 7800),
#  ('wikineural', 21183),
#  ('pannx', 2469),
#  ('wikineural', 56589),
#  ('pannx', 14978),
#  ('aijwikinereswp2', 24218),
#  ('aijwikinereswp2', 3479),
#  ('aijwikinereswp2', 48755),
#  ('pannx', 18552),
#  ('wikineural', 15185),
#  ('aijwikinereswp2', 33131),
#  ('wikineural', 6398),
#  ('pannx', 16706),
#  ('aijwikinereswp2', 9759),
#  ('wikineural', 66301),
#  ('pannx', 6126),
#  ('wikineural', 3472),
#  ('pannx', 9371),
#  ('aijwikinereswp2', 50954),
#  ('wikineural', 19163),
#  ('aijwikinereswp2', 24958),
#  ('aijwikinereswp2', 11606),
#  ('wikineural', 24224),
#  ('pannx', 7966),
#  ('wikineural', 68272),
#  ('wikineural', 15557),
#  ('aijwikinereswp2', 13711),
#  ('wikineural', 17617),
#  ('wikineural', 34802),
#  ('wikineural', 57997),
#  ('wikineural', 16678),
#  ('wikineural', 41020),
#  ('aijwikinereswp2', 37229),
#  ('wikineural', 51247),
#  ('wikineural', 75039),
#  ('aijwikinereswp2', 66632),
#  ('aijwikinereswp2', 58162),
#  ('aijwikinereswp2', 64490),
#  ('aijwikinereswp2', 20764),
#  ('wikineural', 65942),
#  ('wikineural', 46197),
#  ('wikineural', 29596),
#  ('aijwikinereswp2', 40856),
#  ('wikineural', 25313),
#  ('aijwikinereswp2', 56889),
#  ('wikineural', 22578),
#  ('pannx', 7587),
#  ('aijwikinereswp2', 18875),
#  ('wikineural', 12865),
#  ('aijwikinereswp2', 44987),
#  ('pannx', 19128),
#  ('aijwikinereswp2', 14530),
#  ('aijwikinereswp2', 15804),
#  ('aijwikinereswp2', 18086),
#  ('aijwikinereswp2', 25051),
#  ('aijwikinereswp2', 10372),
#  ('aijwikinereswp2', 20250),
#  ('aijwikinereswp2', 46455),
#  ('wikineural', 43901),
#  ('wikineural', 21421),
#  ('aijwikinereswp2', 1942),
#  ('aijwikinereswp2', 25267),
#  ('wikineural', 16234),
#  ('aijwikinereswp2', 22052),
#  ('pannx', 2106),
#  ('aijwikinereswp2', 9823),
#  ('aijwikinereswp2', 39389),
#  ('aijwikinereswp2', 3043),
#  ('wikineural', 56476),
#  ('aijwikinereswp2', 73076),
#  ('wikineural', 54555),
#  ('aijwikinereswp2', 30155),
#  ('aijwikinereswp2', 37681),
#  ('wikineural', 31644),
#  ('pannx', 14545),
#  ('wikineural', 71683),
#  ('wikineural', 11090),
#  ('aijwikinereswp2', 66724),
#  ('wikineural', 48753),
#  ('aijwikinereswp2', 34289),
#  ('aijwikinereswp2', 29839),
#  ('aijwikinereswp2', 67248),
#  ('wikineural', 68102),
#  ('aijwikinereswp2', 25944),
#  ('aijwikinereswp2', 2641),
#  ('wikineural', 75166),
#  ('aijwikinereswp2', 30817),
#  ('pannx', 4008),
#  ('aijwikinereswp2', 51379),
#  ('aijwikinereswp2', 69064),
#  ('aijwikinereswp2', 32564),
#  ('wikineural', 48426),
#  ('wikineural', 57813),
#  ('pannx', 44),
#  ('wikineural', 7373),
#  ('wikineural', 17536),
#  ('pannx', 14667),
#  ('aijwikinereswp2', 3332),
#  ('aijwikinereswp2', 54967),
#  ('pannx', 18301),
#  ('aijwikinereswp2', 45274),
#  ('aijwikinereswp2', 32340),
#  ('pannx', 1272),
#  ('aijwikinereswp2', 69919),
#  ('wikineural', 54219),
#  ('wikineural', 15799),
#  ('aijwikinereswp2', 54364),
#  ('aijwikinereswp2', 42351),
#  ('wikineural', 48771),
#  ('pannx', 19427),
#  ('aijwikinereswp2', 74540),
#  ('pannx', 14323),
#  ('wikineural', 66813),
#  ('pannx', 4135),
#  ('wikineural', 70570),
#  ('aijwikinereswp2', 30482),
#  ('aijwikinereswp2', 60579),
#  ('wikineural', 35300),
#  ('aijwikinereswp2', 30052),
#  ('wikineural', 48725),
#  ('aijwikinereswp2', 24167),
#  ('aijwikinereswp2', 26651),
#  ('aijwikinereswp2', 76123),
#  ('wikineural', 23069),
#  ('wikineural', 20386),
#  ('wikineural', 63212),
#  ('wikineural', 68778),
#  ('wikineural', 15724),
#  ('aijwikinereswp2', 12933),
#  ('wikineural', 40036),
#  ('wikineural', 17925),
#  ('aijwikinereswp2', 64735),
#  ('aijwikinereswp2', 51176),
#  ('aijwikinereswp2', 49897),
#  ('aijwikinereswp2', 10326),
#  ('wikineural', 19731),
#  ('wikineural', 75444),
#  ('aijwikinereswp2', 67409),
#  ('aijwikinereswp2', 49608),
#  ('pannx', 18949),
#  ('pannx', 16985),
#  ('aijwikinereswp2', 65552),
#  ('wikineural', 11279),
#  ('aijwikinereswp2', 6494),
#  ('wikineural', 48580),
#  ('wikineural', 22669),
#  ('aijwikinereswp2', 57593),
#  ('wikineural', 25372),
#  ('aijwikinereswp2', 6259),
#  ('pannx', 10551),
#  ('wikineural', 72632),
#  ('aijwikinereswp2', 46603),
#  ('wikineural', 53781),
#  ('aijwikinereswp2', 65338),
#  ('wikineural', 7057),
#  ('pannx', 17770),
#  ('wikineural', 57578),
#  ('wikineural', 21129),
#  ('aijwikinereswp2', 67211),
#  ('aijwikinereswp2', 71464),
#  ('aijwikinereswp2', 10485),
#  ('wikineural', 51827),
#  ('wikineural', 51642),
#  ('pannx', 17749),
#  ('aijwikinereswp2', 64454),
#  ('aijwikinereswp2', 62855),
#  ('wikineural', 27787),
#  ('aijwikinereswp2', 63625),
#  ('wikineural', 30397),
#  ('aijwikinereswp2', 71427),
#  ('aijwikinereswp2', 10615),
#  ('aijwikinereswp2', 947),
#  ('wikineural', 34471),
#  ('aijwikinereswp2', 70179),
#  ('wikineural', 43079),
#  ('wikineural', 59604),
#  ('wikineural', 7982),
#  ('aijwikinereswp2', 65456),
#  ('pannx', 7635),
#  ('aijwikinereswp2', 5791),
#  ('pannx', 11176),
#  ('wikineural', 23129),
#  ('wikineural', 68135),
#  ('aijwikinereswp2', 1642),
#  ('wikineural', 72781),
#  ('wikineural', 50590),
#  ('aijwikinereswp2', 66157),
#  ('wikineural', 69641),
#  ('aijwikinereswp2', 37525),
#  ('aijwikinereswp2', 74725),
#  ('wikineural', 48577),
#  ('pannx', 5026),
#  ('wikineural', 40726),
#  ('wikineural', 73916),
#  ('aijwikinereswp2', 57471),
#  ('wikineural', 73111),
#  ('wikineural', 19432),
#  ('aijwikinereswp2', 61672),
#  ('wikineural', 35692),
#  ('wikineural', 19559),
#  ('wikineural', 19063),
#  ('wikineural', 51154),
#  ('aijwikinereswp2', 38282),
#  ('aijwikinereswp2', 8732),
#  ('aijwikinereswp2', 53569),
#  ('aijwikinereswp2', 15796),
#  ('aijwikinereswp2', 63159),
#  ('aijwikinereswp2', 30783),
#  ('aijwikinereswp2', 76395),
#  ('wikineural', 2474),
#  ('wikineural', 35141),
#  ('wikineural', 37295),
#  ('wikineural', 1407),
#  ('wikineural', 44930),
#  ('aijwikinereswp2', 53410),
#  ('aijwikinereswp2', 58953),
#  ('aijwikinereswp2', 18109),
#  ('wikineural', 70350),
#  ('aijwikinereswp2', 20844),
#  ('aijwikinereswp2', 48714),
#  ('aijwikinereswp2', 5285),
#  ('wikineural', 43309),
#  ('wikineural', 7935),
#  ('aijwikinereswp2', 70973),
#  ('aijwikinereswp2', 13482),
#  ('aijwikinereswp2', 4011),
#  ('wikineural', 26203),
#  ('wikineural', 46009),
#  ('wikineural', 66677),
#  ('wikineural', 893),
#  ('wikineural', 6998),
#  ('wikineural', 48369),
#  ('wikineural', 46723),
#  ('wikineural', 10054),
#  ('aijwikinereswp2', 33221),
#  ('aijwikinereswp2', 48281),
#  ('aijwikinereswp2', 4512),
#  ('aijwikinereswp2', 43353),
#  ('pannx', 14749),
#  ('wikineural', 46959),
#  ('wikineural', 28823),
#  ('wikineural', 1373),
#  ('wikineural', 50772),
#  ('aijwikinereswp2', 37843),
#  ('pannx', 5365),
#  ('aijwikinereswp2', 37859),
#  ('wikineural', 72538),
#  ('wikineural', 13274),
#  ('pannx', 19610),
#  ('aijwikinereswp2', 30937),
#  ('wikineural', 43134),
#  ('aijwikinereswp2', 41072),
#  ('pannx', 11517),
#  ('wikineural', 63045),
#  ('pannx', 3467),
#  ('aijwikinereswp2', 1267),
#  ('aijwikinereswp2', 49697),
#  ('wikineural', 5998),
#  ('aijwikinereswp2', 21713),
#  ('wikineural', 71347),
#  ('pannx', 12423),
#  ('wikineural', 28768),
#  ('wikineural', 57171),
#  ('wikineural', 21144),
#  ('aijwikinereswp2', 44267),
#  ('wikineural', 36448),
#  ('aijwikinereswp2', 16224),
#  ('wikineural', 40837),
#  ('aijwikinereswp2', 71640),
#  ('aijwikinereswp2', 22820),
#  ('wikineural', 12556),
#  ('pannx', 5041),
#  ('wikineural', 58407),
#  ('pannx', 510),
#  ('wikineural', 38014),
#  ('aijwikinereswp2', 2353),
#  ('wikineural', 48696),
#  ('pannx', 9796),
#  ('aijwikinereswp2', 33628),
#  ('wikineural', 3253),
#  ('pannx', 13514),
#  ('pannx', 12057),
#  ('pannx', 1527),
#  ('aijwikinereswp2', 71797),
#  ('aijwikinereswp2', 65729),
#  ('wikineural', 22870),
#  ('aijwikinereswp2', 34273),
#  ('aijwikinereswp2', 45917),
#  ('wikineural', 30544),
#  ('wikineural', 19524),
#  ('wikineural', 10382),
#  ('aijwikinereswp2', 51837),
#  ('aijwikinereswp2', 32474),
#  ('aijwikinereswp2', 30394),
#  ('wikineural', 65657),
#  ('wikineural', 33813),
#  ('wikineural', 50098),
#  ('aijwikinereswp2', 23327),
#  ('aijwikinereswp2', 56495),
#  ('aijwikinereswp2', 72720),
#  ('aijwikinereswp2', 45078),
#  ('aijwikinereswp2', 52766),
#  ('wikineural', 46569),
#  ('wikineural', 42149),
#  ('aijwikinereswp2', 8876),
#  ('wikineural', 75410),
#  ('aijwikinereswp2', 70032),
#  ('pannx', 7010),
#  ('aijwikinereswp2', 69155),
#  ('wikineural', 56626),
#  ('wikineural', 45437),
#  ('wikineural', 263),
#  ('aijwikinereswp2', 327),
#  ('wikineural', 34794),
#  ('aijwikinereswp2', 26717),
#  ('wikineural', 28618),
#  ('aijwikinereswp2', 42212),
#  ('wikineural', 11621),
#  ('aijwikinereswp2', 5825),
#  ('wikineural', 43066),
#  ('aijwikinereswp2', 13250),
#  ('pannx', 19424),
#  ('wikineural', 20343),
#  ('wikineural', 61154),
#  ('aijwikinereswp2', 5493),
#  ('aijwikinereswp2', 68420),
#  ('aijwikinereswp2', 9036),
#  ('aijwikinereswp2', 72688),
#  ('wikineural', 33493),
#  ('wikineural', 67802),
#  ('aijwikinereswp2', 73615),
#  ('wikineural', 31619),
#  ('aijwikinereswp2', 29799),
#  ('wikineural', 76252),
#  ('wikineural', 31132),
#  ('aijwikinereswp2', 47872),
#  ('wikineural', 36505),
#  ('wikineural', 30451),
#  ('aijwikinereswp2', 64512),
#  ('aijwikinereswp2', 19138),
#  ('wikineural', 58134),
#  ('wikineural', 4650),
#  ('aijwikinereswp2', 17749),
#  ('aijwikinereswp2', 67017),
#  ('aijwikinereswp2', 43535),
#  ('aijwikinereswp2', 66877),
#  ('wikineural', 57608),
#  ('wikineural', 63772),
#  ('aijwikinereswp2', 18901),
#  ('aijwikinereswp2', 30835),
#  ('aijwikinereswp2', 48051),
#  ('aijwikinereswp2', 38059),
#  ('aijwikinereswp2', 49199),
#  ('wikineural', 27994),
#  ('wikineural', 67573),
#  ('aijwikinereswp2', 32132),
#  ('aijwikinereswp2', 44119),
#  ('pannx', 12258),
#  ('wikineural', 39492),
#  ('wikineural', 42460),
#  ('aijwikinereswp2', 42817),
#  ('pannx', 14952),
#  ('aijwikinereswp2', 75157),
#  ('wikineural', 2007),
#  ('aijwikinereswp2', 69146),
#  ('pannx', 440),
#  ('wikineural', 49620),
#  ('wikineural', 56267),
#  ('wikineural', 76121),
#  ('wikineural', 53640),
#  ('aijwikinereswp2', 57302),
#  ('wikineural', 1783),
#  ('aijwikinereswp2', 38204),
#  ('wikineural', 12460),
#  ('wikineural', 19030),
#  ('wikineural', 33966),
#  ('aijwikinereswp2', 55504),
#  ('aijwikinereswp2', 38383),
#  ('aijwikinereswp2', 691),
#  ('wikineural', 9281),
#  ('aijwikinereswp2', 29492),
#  ('wikineural', 57410),
#  ('wikineural', 40604),
#  ('wikineural', 32961),
#  ('wikineural', 10135),
#  ('aijwikinereswp2', 47960),
#  ('wikineural', 25477),
#  ('wikineural', 31551),
#  ('pannx', 13473),
#  ('wikineural', 32415),
#  ('pannx', 19121),
#  ('wikineural', 63839),
#  ('wikineural', 1058),
#  ('wikineural', 2772),
#  ('aijwikinereswp2', 72753),
#  ('wikineural', 42318),
#  ('aijwikinereswp2', 30113),
#  ('wikineural', 72301),
#  ('pannx', 7765),
#  ('aijwikinereswp2', 26013),
#  ('aijwikinereswp2', 66198),
#  ('wikineural', 28216),
#  ('wikineural', 19890),
#  ('wikineural', 56919),
#  ('aijwikinereswp2', 59436),
#  ('wikineural', 69246),
#  ('pannx', 18818),
#  ('aijwikinereswp2', 65158),
#  ('pannx', 17331),
#  ('wikineural', 39107),
#  ('aijwikinereswp2', 9053),
#  ('wikineural', 31651),
#  ('aijwikinereswp2', 53625),
#  ('pannx', 9254),
#  ('wikineural', 26239),
#  ('wikineural', 11938),
#  ('wikineural', 15442),
#  ('wikineural', 17066),
#  ('aijwikinereswp2', 58785),
#  ('aijwikinereswp2', 30277),
#  ('wikineural', 5512),
#  ('aijwikinereswp2', 6045),
#  ('pannx', 16189),
#  ('wikineural', 15893),
#  ('wikineural', 35857),
#  ('wikineural', 19950),
#  ('wikineural', 73525),
#  ('aijwikinereswp2', 47865),
#  ('wikineural', 1648),
#  ('aijwikinereswp2', 33215),
#  ('aijwikinereswp2', 59643),
#  ('wikineural', 53503),
#  ('aijwikinereswp2', 11435),
#  ('wikineural', 31272),
#  ('wikineural', 72787),
#  ('aijwikinereswp2', 27156),
#  ('wikineural', 54169),
#  ('wikineural', 61559),
#  ('aijwikinereswp2', 44465),
#  ('aijwikinereswp2', 55032),
#  ('pannx', 5007),
#  ('wikineural', 24650),
#  ('pannx', 5776),
#  ('aijwikinereswp2', 21015),
#  ('aijwikinereswp2', 54199),
#  ('wikineural', 76032),
#  ('aijwikinereswp2', 60338),
#  ('wikineural', 37570),
#  ('aijwikinereswp2', 22367),
#  ('wikineural', 58647),
#  ('wikineural', 14034),
#  ('aijwikinereswp2', 14773),
#  ('aijwikinereswp2', 60471),
#  ('pannx', 11828),
#  ('wikineural', 64171),
#  ('wikineural', 53025),
#  ('wikineural', 42310),
#  ('wikineural', 20746),
#  ('wikineural', 15468),
#  ('aijwikinereswp2', 32634),
#  ('aijwikinereswp2', 59018),
#  ('wikineural', 69163),
#  ('wikineural', 48215),
#  ('wikineural', 30870),
#  ('aijwikinereswp2', 11648),
#  ('wikineural', 35125),
#  ('pannx', 5190),
#  ('aijwikinereswp2', 8957),
#  ('aijwikinereswp2', 56948),
#  ('wikineural', 31082),
#  ('aijwikinereswp2', 53003),
#  ('aijwikinereswp2', 44163),
#  ('aijwikinereswp2', 74148),
#  ('wikineural', 59193),
#  ('aijwikinereswp2', 22677),
#  ('aijwikinereswp2', 19872),
#  ('wikineural', 29516),
#  ('aijwikinereswp2', 39758),
#  ('pannx', 11620),
#  ('aijwikinereswp2', 52704),
#  ('wikineural', 71160),
#  ('pannx', 13712),
#  ('wikineural', 27885),
#  ('aijwikinereswp2', 39441),
#  ('wikineural', 8767),
#  ('wikineural', 40803),
#  ('aijwikinereswp2', 61367),
#  ('aijwikinereswp2', 43725),
#  ('aijwikinereswp2', 67671),
#  ('aijwikinereswp2', 30571),
#  ('wikineural', 27959),
#  ('wikineural', 54339),
#  ('wikineural', 10998),
#  ('wikineural', 68269),
#  ('wikineural', 14318),
#  ('aijwikinereswp2', 445),
#  ('wikineural', 65093),
#  ('aijwikinereswp2', 49984),
#  ('pannx', 15720),
#  ('pannx', 8519),
#  ('wikineural', 74871),
#  ('aijwikinereswp2', 7685),
#  ('wikineural', 48164),
#  ('aijwikinereswp2', 76117),
#  ('aijwikinereswp2', 66901),
#  ('aijwikinereswp2', 3444),
#  ('aijwikinereswp2', 72316),
#  ('aijwikinereswp2', 6326),
#  ('aijwikinereswp2', 45858),
#  ('aijwikinereswp2', 14671),
#  ('wikineural', 69174),
#  ('aijwikinereswp2', 20846),
#  ('wikineural', 44160),
#  ('wikineural', 37455),
#  ('wikineural', 49690),
#  ('wikineural', 63932),
#  ('wikineural', 30704),
#  ('aijwikinereswp2', 35062),
#  ('aijwikinereswp2', 13741),
#  ('pannx', 11101),
#  ('aijwikinereswp2', 70857),
#  ('pannx', 15267),
#  ('aijwikinereswp2', 34750),
#  ('aijwikinereswp2', 18057),
#  ('aijwikinereswp2', 46097),
#  ('wikineural', 18426),
#  ('aijwikinereswp2', 50766),
#  ('aijwikinereswp2', 72218),
#  ('aijwikinereswp2', 5939),
#  ('wikineural', 29493),
#  ('aijwikinereswp2', 59542),
#  ('wikineural', 13880),
#  ('pannx', 19227),
#  ('aijwikinereswp2', 62391),
#  ('wikineural', 12847),
#  ('aijwikinereswp2', 2054),
#  ('wikineural', 25233),
#  ('pannx', 4906),
#  ('aijwikinereswp2', 75723),
#  ('aijwikinereswp2', 56225),
#  ('wikineural', 30139),
#  ('wikineural', 18300),
#  ('wikineural', 42126),
#  ('pannx', 1049),
#  ('aijwikinereswp2', 38676),
#  ('wikineural', 55863),
#  ('wikineural', 36707),
#  ('wikineural', 44414),
#  ('wikineural', 13736),
#  ('wikineural', 30746),
#  ('aijwikinereswp2', 41050),
#  ('wikineural', 65932),
#  ('wikineural', 74293),
#  ('wikineural', 56465),
#  ('aijwikinereswp2', 48636),
#  ('aijwikinereswp2', 66267),
#  ('pannx', 18187),
#  ('pannx', 3311),
#  ('aijwikinereswp2', 49941),
#  ('aijwikinereswp2', 74855),
#  ('wikineural', 17262),
#  ('wikineural', 18546),
#  ('aijwikinereswp2', 71795),
#  ('wikineural', 22171),
#  ('pannx', 17291),
#  ('wikineural', 22927),
#  ('wikineural', 43320),
#  ('wikineural', 6346),
#  ('wikineural', 4292),
#  ('aijwikinereswp2', 26912),
#  ('wikineural', 38136),
#  ('aijwikinereswp2', 74468),
#  ('pannx', 4628),
#  ('wikineural', 65913),
#  ('aijwikinereswp2', 23135),
#  ('aijwikinereswp2', 26383),
#  ('aijwikinereswp2', 40213),
#  ('wikineural', 45995),
#  ('wikineural', 64971),
#  ('wikineural', 2720),
#  ('pannx', 18037),
#  ('wikineural', 61998),
#  ('aijwikinereswp2', 596),
#  ('aijwikinereswp2', 61020),
#  ('aijwikinereswp2', 19655),
#  ('aijwikinereswp2', 25093),
#  ('wikineural', 20218),
#  ('wikineural', 37306),
#  ('aijwikinereswp2', 57559),
#  ('wikineural', 57852),
#  ('aijwikinereswp2', 35913),
#  ('aijwikinereswp2', 68222),
#  ('aijwikinereswp2', 59638),
#  ('wikineural', 68101),
#  ('aijwikinereswp2', 69760),
#  ('wikineural', 20629),
#  ('wikineural', 41214),
#  ('aijwikinereswp2', 7953),
#  ('aijwikinereswp2', 52646),
#  ('wikineural', 4586),
#  ('wikineural', 24505),
#  ('pannx', 19134),
#  ('pannx', 7603),
#  ('aijwikinereswp2', 65250),
#  ('aijwikinereswp2', 70340),
#  ('wikineural', 52231),
#  ('wikineural', 63069),
#  ('wikineural', 942),
#  ('aijwikinereswp2', 66733),
#  ('aijwikinereswp2', 18959),
#  ('wikineural', 18258),
#  ('aijwikinereswp2', 31155),
#  ('aijwikinereswp2', 61955),
#  ('wikineural', 6451),
#  ('aijwikinereswp2', 8010),
#  ('aijwikinereswp2', 28235),
#  ('aijwikinereswp2', 68774),
#  ('aijwikinereswp2', 14729),
#  ('wikineural', 9278),
#  ('wikineural', 25403),
#  ('aijwikinereswp2', 9344),
#  ('aijwikinereswp2', 74619),
#  ('wikineural', 13295),
#  ('wikineural', 6094),
#  ('wikineural', 56071),
#  ('wikineural', 51290),
#  ('wikineural', 8793),
#  ('aijwikinereswp2', 7276),
#  ('aijwikinereswp2', 25211),
#  ('aijwikinereswp2', 44109),
#  ('aijwikinereswp2', 16166),
#  ('wikineural', 62974),
#  ('aijwikinereswp2', 17019),
#  ('wikineural', 20022),
#  ('aijwikinereswp2', 76988),
#  ('wikineural', 58269),
#  ('aijwikinereswp2', 10414),
#  ('aijwikinereswp2', 38225),
#  ('aijwikinereswp2', 3078),
#  ('pannx', 13308),
#  ('aijwikinereswp2', 72524),
#  ('aijwikinereswp2', 64518),
#  ('pannx', 18145),
#  ('aijwikinereswp2', 75860),
#  ('aijwikinereswp2', 34236),
#  ('aijwikinereswp2', 22533),
#  ('wikineural', 32774),
#  ('wikineural', 44685),
#  ('aijwikinereswp2', 48097),
#  ('aijwikinereswp2', 11280),
#  ('aijwikinereswp2', 11800),
#  ('aijwikinereswp2', 74131),
#  ('aijwikinereswp2', 65253),
#  ('aijwikinereswp2', 4391),
#  ('wikineural', 44060),
#  ('wikineural', 47937),
#  ('aijwikinereswp2', 22455),
#  ('wikineural', 53099),
#  ('wikineural', 148),
#  ('aijwikinereswp2', 75876),
#  ('wikineural', 62319),
#  ('aijwikinereswp2', 73852),
#  ('pannx', 18889),
#  ('aijwikinereswp2', 32577),
#  ('wikineural', 54486),
#  ('wikineural', 66665),
#  ('pannx', 792),
#  ('wikineural', 32277),
#  ('wikineural', 38979),
#  ('aijwikinereswp2', 35079),
#  ('pannx', 6742),
#  ('pannx', 19212),
#  ('aijwikinereswp2', 38749),
#  ('wikineural', 21965),
#  ('aijwikinereswp2', 56934),
#  ('wikineural', 70614),
#  ('wikineural', 5879),
#  ('aijwikinereswp2', 66256),
#  ('pannx', 15072),
#  ('pannx', 18618),
#  ('wikineural', 24171),
#  ('aijwikinereswp2', 12543),
#  ('aijwikinereswp2', 62547),
#  ('aijwikinereswp2', 26506),
#  ('wikineural', 74219),
#  ('aijwikinereswp2', 27111),
#  ('aijwikinereswp2', 61043),
#  ('wikineural', 40133),
#  ('wikineural', 5848),
#  ('wikineural', 58885),
#  ('wikineural', 54530),
#  ('aijwikinereswp2', 60139),
#  ('aijwikinereswp2', 23883),
#  ('aijwikinereswp2', 60873),
#  ('aijwikinereswp2', 68075),
#  ('wikineural', 66059),
#  ('wikineural', 40212),
#  ('wikineural', 7430),
#  ('wikineural', 65286),
#  ('aijwikinereswp2', 10185),
#  ('aijwikinereswp2', 63481),
#  ('pannx', 2426),
#  ('pannx', 16984),
#  ('wikineural', 54260),
#  ('wikineural', 14600),
#  ('wikineural', 52255),
#  ('aijwikinereswp2', 72112),
#  ('aijwikinereswp2', 59567),
#  ('wikineural', 7832),
#  ...]

# %%
train_rdg = train_rd.groupby([1,2])

# %%
# create IOB file
import tqdm

with open("train.iob","w",encoding="UTF-8") as file:
    for g in tqdm.tqdm(random_index):
        train_g = train_rdg.get_group(g)
        for r in train_g.to_records():
            #file.write(f"{r['3'].encode('UTF-8').decode('UTF-8')}\t{r['4'].encode('UTF-8').decode('UTF-8')}\n")
            file.write(f"{r['3']} {r['4']}\n")
        # space after one sentence
        file.write("\n")
# Out:
# 100%|█████████████████████████████████| 173333/173333 [02:23<00:00, 1203.90it/s]

# %%
train_rd = pd.DataFrame(test_list)

# %%
train_rdg = train_rd.groupby([1,2])

# %%
# create IOB file
import tqdm

with open("test.iob","w") as file:
    for g in tqdm.tqdm(train_rdg.count().index):
        train_g = train_rdg.get_group(g)
        for r in train_g.to_records():
            file.write(f"{r['3']} {r['4']}\n")
        # space after one sentence
        file.write("\n")
# Out:
# 100%|███████████████████████████████████| 35290/35290 [00:31<00:00, 1105.16it/s]

# %%
train_rd = pd.DataFrame(val_list)

# %%
train_rdg = train_rd.groupby([1,2])

# %%
# create IOB file
import tqdm

with open("val.iob","w") as file:
    for g in tqdm.tqdm(train_rdg.count().index):
        train_g = train_rdg.get_group(g)
        for r in train_g.to_records():
            file.write(f"{r['3']}\t{r['4']}\n")
        # space after one sentence
        file.write("\n")
# Out:
# 100%|███████████████████████████████████| 35212/35212 [00:30<00:00, 1147.31it/s]

# %%
import locale

# %%
# !wc -l *.iob
# Out:
#     1000 aha.iob
#  1014988 test.iob
#  4306983 train.iob
#  1015448 val.iob
#  6338419 total

# %% [markdown]
# # convert into spacy datasets

# %%
#!PYTHONIOENCODING="ISO 8859-1" python -m spacy convert -c iob -s -n 5 -t spacy train.iob .
# !python -m spacy convert -c iob -s -n 5 -t spacy train.iob .
# Out:
# ℹ Auto-detected token-per-line NER format
# ⚠ Sentence boundaries found, automatic sentence segmentation with `-s`
# disabled.
# ℹ Grouping every 5 sentences into a document.
# ✔ Generated output file (34667 documents): train.spacy

# %%
# !python -m spacy convert -c iob -s -n 5 -t spacy test.iob .
# Out:
# ℹ Auto-detected token-per-line NER format
# ⚠ Sentence boundaries found, automatic sentence segmentation with `-s`
# disabled.
# ℹ Grouping every 5 sentences into a document.
# ✔ Generated output file (7058 documents): test.spacy

# %%
#!PYTHONIOENCODING="ISO 8859-1" python -m spacy convert -c iob -s -n 5 -t spacy train.iob .
# !python -m spacy convert -c iob -s -n 5 -t spacy val.iob .
# Out:
# ℹ Auto-detected token-per-line NER format
# ⚠ Sentence boundaries found, automatic sentence segmentation with `-s`
# disabled.
# ℹ Grouping every 5 sentences into a document.
# ✔ Generated output file (7043 documents): val.spacy
